# %%
import os


class Para:
    read_folder_path = 'data/sk_space_1d_rate_20d_22-22_raw'
    write_folder_path = 'data/sk_space_1d_rate_20d_22-22_pre'

    feature_column_start_name = 'ep_ratio_ttm'
    feature_column_end_name = 'BR'

    month_num = len(os.listdir(read_folder_path))
para = Para()
print(para.month_num)
# Out:
# 31

# %%
import time
import numpy as np
import pandas as pd


time_begin = time.time()

df = pd.DataFrame()

for i_csv in range(para.month_num):

    df_curr_month = pd.read_csv(para.read_folder_path +'/'+ str(i_csv) + '.csv', index_col='order_book_id')

    df_curr_month['date'] = pd.to_datetime(df_curr_month['date'])

    df = pd.concat([df, df_curr_month])

df
# Out:
#               board_type sector_code  yield_rate  month       date  \
# order_book_id
# 600376.XSHG    MainBoard  RealEstate    0.034722      0 2022-01-04
# 600376.XSHG    MainBoard  RealEstate    0.000000      1 2022-01-05
# 600376.XSHG    MainBoard  RealEstate    0.018676      2 2022-01-06
# 600376.XSHG    MainBoard  RealEstate   -0.011667      3 2022-01-07
# 600376.XSHG    MainBoard  RealEstate   -0.028571      4 2022-01-10
# 600376.XSHG    MainBoard  RealEstate   -0.073892      5 2022-01-11
# 600376.XSHG    MainBoard  RealEstate   -0.092532      6 2022-01-12
# 600376.XSHG    MainBoard  RealEstate   -0.106452      7 2022-01-13
# 600376.XSHG    MainBoard  RealEstate   -0.078176      8 2022-01-14
# 600376.XSHG    MainBoard  RealEstate   -0.065359      9 2022-01-17
# 600376.XSHG    MainBoard  RealEstate   -0.059504     10 2022-01-18
# 600376.XSHG    MainBoard  RealEstate   -0.088380     11 2022-01-19
# 600376.XSHG    MainBoard  RealEstate   -0.092409     12 2022-01-20
# 600376.XSHG    MainBoard  RealEstate   -0.105437     13 2022-01-21
# 600376.XSHG    MainBoard  RealEstate   -0.106908     14 2022-01-24
# 600376.XSHG    MainBoard  RealEstate   -0.085714     15 2022-01-25
# 600376.XSHG    MainBoard  RealEstate   -0.070826     16 2022-01-26
# 600376.XSHG    MainBoard  RealEstate   -0.032479     17 2022-01-27
# 600376.XSHG    MainBoard  RealEstate   -0.011966     18 2022-01-28
# 600376.XSHG    MainBoard  RealEstate   -0.001706     19 2022-02-07
# 600376.XSHG    MainBoard  RealEstate   -0.052013     20 2022-02-08
# 600376.XSHG    MainBoard  RealEstate   -0.115059     21 2022-02-09
# 600376.XSHG    MainBoard  RealEstate   -0.116667     22 2022-02-10
# 600376.XSHG    MainBoard  RealEstate   -0.107926     23 2022-02-11
# 600376.XSHG    MainBoard  RealEstate   -0.096886     24 2022-02-14
# 600376.XSHG    MainBoard  RealEstate   -0.138298     25 2022-02-15
# 600376.XSHG    MainBoard  RealEstate   -0.103757     26 2022-02-16
# 600376.XSHG    MainBoard  RealEstate   -0.063177     27 2022-02-17
# 600376.XSHG    0.324579  0.211408  0.466017  181.067961  192.039801
# 600376.XSHG    0.326295  0.229780  0.484127  177.403846  181.067961
# 600376.XSHG    0.328023  0.239409  0.499136  166.509434  170.000000
# 600376.XSHG    0.329720  0.238987  0.508249  156.038647  147.441860
# 600376.XSHG    0.331292  0.231087  0.519410  154.455446  146.889952
# 600376.XSHG    0.332656  0.238060  0.530879  158.793970  152.195122
# 600376.XSHG    0.333985  0.238325  0.538670  145.283019  149.760766
# 600376.XSHG    0.333911  0.226776  0.545473  138.356164  141.474654
# 600376.XSHG    0.333426  0.214240  0.552460  132.300885  137.387387
# 600376.XSHG    0.333525  0.193131  0.553514  135.267857  137.219731
# 600376.XSHG    0.334992  0.174443  0.552106  130.508475  131.355932
# 600376.XSHG    0.336201  0.155533  0.550407  115.226337  114.344262
# 600376.XSHG    0.337444  0.142174  0.546897  117.647059  124.242424
# 600376.XSHG    0.338917  0.123428  0.541460  129.385965  125.431034
# 600376.XSHG    0.340091  0.110228  0.537200  149.763033  130.131004
# 600376.XSHG    0.340705  0.110228  0.529964  142.201835  130.567686
# 600376.XSHG    0.339181  0.106529  0.524212  148.584906  131.140351
# 600376.XSHG    0.340467  0.108253  0.519843  136.036036  127.826087
# 600376.XSHG    0.341416  0.119583  0.512316  129.613734  115.725806
# 600376.XSHG    0.341689  0.142824  0.502983  115.725806  108.171206
# 600376.XSHG    0.342906  0.161226  0.492356  113.306452  108.267717
# 600376.XSHG    0.342702  0.175166  0.480470   99.601594   94.941634
# 600376.XSHG    0.343156  0.176459  0.467708  100.000000   98.412698
# 600376.XSHG    0.344318  0.172477  0.455845   91.085271   90.347490
# 600376.XSHG    0.344730  0.172257  0.440606   97.540984   93.574297
#
# [31 rows x 21 columns]

# %%
# Replace infinite updated data with nan
df.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

# 剔除含有 na 的行
df_dropna = df.dropna(axis=0, how='any')

# 选择特征列和标签列
df_dropna_y = df_dropna[['board_type', 'sector_code', 'month', 'date']]
df_dropna_features = df_dropna.loc[:, para.feature_column_start_name:para.feature_column_end_name]
df_dropna_features = pd.concat([df_dropna['yield_rate'], df_dropna_features], axis=1)

# 中位数去极值
df_dropna_features = df_dropna_features.clip(
    lower=df_dropna_features.median(axis=0) - 5 * df_dropna_features.mad(axis=0),
    upper=df_dropna_features.median(axis=0) + 5 * df_dropna_features.mad(axis=0),
    axis=1)

# 标准化
df_dropna_features = (df_dropna_features - df_dropna_features.mean()) / df_dropna_features.std(ddof=0)

# 拼接标签列和特征列
df_dropna_standard = pd.concat([df_dropna_y, df_dropna_features], axis=1)

# 写入文件
df_dropna_standard.to_csv(para.write_folder_path + '/0.csv')

print()
print('Done!')
# Out:
# Done!
